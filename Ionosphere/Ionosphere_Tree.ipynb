# %%
"""
Authors: Mariusz Krzyzopolski s21544 Tomasz Baj s20499
"""
# Out:
# '\nAuthors: Mariusz Krzyzopolski s21544 Tomasz Baj s20499\n'

# %%
import matplotlib.pyplot as plt
from sklearn import tree
import pandas as pd

# %%
data = pd.read_csv("ionosphere.data", header=None)
data.head()
# Out:
#    0   1        2        3        4        5        6        7        8   \
# 0   1   0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1   1   0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 2   1   0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 3   1   0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 4   1   0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
#
#         9   ...       25       26       27       28       29       30  \
# 0  0.03760  ... -0.51171  0.41078 -0.46168  0.21266 -0.34090  0.42267
# 1 -0.04549  ... -0.26569 -0.20468 -0.18401 -0.19040 -0.11593 -0.16626
# 2  0.01198  ... -0.40220  0.58984 -0.22145  0.43100 -0.17365  0.60436
# 3  0.00000  ...  0.90695  0.51613  1.00000  1.00000 -0.20099  0.25682
# 4 -0.16399  ... -0.65158  0.13290 -0.53206  0.02431 -0.62197 -0.05707
#
#         31       32       33  34
# 0 -0.54487  0.18641 -0.45300   g
# 1 -0.06288 -0.13738 -0.02447   b
# 2 -0.24180  0.56045 -0.38238   g
# 3  1.00000 -0.32382  1.00000   b
# 4 -0.59573 -0.04608 -0.65697   g
#
# [5 rows x 35 columns]

# %%
"""Prepare test and train datasets"""

X = data.iloc[:,0:34]
Y = data.iloc[:,34]
X_train = data.iloc[0:199, 0:34]
y_train = data.iloc[0:199, 34]
X_test = data.iloc[200:, 0:34]
y_test = data.iloc[200:, 34]

# %%
"""Create decision tree classifier and train it with X and y training datasets"""

dec_tree = tree.DecisionTreeClassifier().fit(X_train, y_train)

# %%
"""Evaluate classifier with train and test datasets"""

print(f"Score for train test: {dec_tree.score(X_train, y_train)}")
print(f"Score for test set: {dec_tree.score(X_test, y_test)}")
# Out:
# Score for train test: 1.0
# Score for test set: 0.8940397350993378

# %%
"""Plot Decision tree"""

fig = plt.figure(figsize=(25,20))
feature=[str(i) for i in X.columns]
_ = tree.plot_tree(dec_tree, feature_names=feature, class_names=['g','r'], filled=True)
